# %% [markdown]
# # 3.使用卷积神经网络对手写数字做分类

# %% [markdown]
# ## 1. 获取数据

# %%
from torchvision import datasets,transforms 
import torch

batch_size = 64  #一个（批次）的大小，64张图片

# 训练集
train_dataset = datasets.MNIST(root='../data/3/',  
                            train=True,   
                            transform=transforms.ToTensor(),  
                            download=True) 

# 测试集
test_dataset = datasets.MNIST(root='../data/3/', 
                           train=False, 
                           transform=transforms.ToTensor())


# 构建batch数据
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

# 训练集 60000 条数据
print(train_dataset.data.shape) 
print(train_dataset.targets.shape)

# 测试集 10000 条数据
print(test_dataset.data.shape) 
print(test_dataset.targets.shape)

print(train_loader)
print(test_loader)
# Out:
# torch.Size([60000, 28, 28])
# torch.Size([60000])
# torch.Size([10000, 28, 28])
# torch.Size([10000])
# <torch.utils.data.dataloader.DataLoader object at 0x13ab2d840>
# <torch.utils.data.dataloader.DataLoader object at 0x107b568f0>

# %% [markdown]
# ### 1. 打印数据
# 展示训练集前6条数据

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 6, figsize=(24, 4))

for i in range(6):
    ax[i].imshow(train_dataset.data[i].reshape((28, 28)), cmap='gray')
    ax[i].set_title(f'train_dataset.data[{i}]')

print(f'train_dataset.targets[:6]:{train_dataset.targets[:6]}')
# Out:
# train_dataset.targets[:6]:tensor([5, 0, 4, 1, 9, 2])
